# %% [markdown]
# # Web Scraping
#
# Last time, we looked at REST API's as a source of data. You can get lots of very high quality data this way.
#
# Some data is available online, but not through an API. When this is the case, some times you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with.

# %% [markdown]
# We'll be scraping data about used cars in Charlottesville from Craigslist. This will give us a chance to put those wrangling, EDA, and visualization skills to work.
#
# We'll use the `requests` package, as we did with API's, but will be getting the kinds of web pages you see everyday. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](craigslist.png "Craigslist")
#
# But if you "view page source" or
# (right click and choose "view page source") -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tages, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.

# %% [markdown]
# ## 1. Pick something else on Craigslist: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of EDA you'd do with it.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html, passing raw data saved above into beautifulsoup
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %%
listings #shows all listings from craiglists
listings[1] # shows second listing (indexing starts at 0)
# Out:
# [<li class="cl-static-search-result" title="2015 Honda Odyssey EX">
#  <a href="https://charlottesville.craigslist.org/cto/d/henrico-2015-honda-odyssey-ex/7785813701.html">
#  <div class="title">2015 Honda Odyssey EX</div>
#  <div class="details">
#  <div class="price">$9,950</div>
#  <div class="location">
#                          Short Pump
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2005 Hyundai Elantra">
#  <a href="https://charlottesville.craigslist.org/cto/d/afton-2005-hyundai-elantra/7785683810.html">
#  <div class="title">2005 Hyundai Elantra</div>
#  <div class="details">
#  <div class="price">$1,200</div>
#  <div class="location">
#                          Afton
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 f250 king ranch">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-2007-f250-king-ranch/7785680751.html">
#  <div class="title">2007 f250 king ranch</div>
#  <div class="details">
#  <div class="price">$17,500</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1997 Dodge 2500 4x4 Cummins">
#  <a href="https://charlottesville.craigslist.org/cto/d/lovingston-1997-dodge-x4-cummins/7785609263.html">
#  <div class="title">1997 Dodge 2500 4x4 Cummins</div>
#  <div class="details">
#  <div class="price">$9,500</div>
#  <div class="location">
#                          Lovingston
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1999 Honda Civic 4 Cyl Manual Transmission">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-1999-honda-civic-cyl/7785580889.html">
#  <div class="title">1999 Honda Civic 4 Cyl Manual Transmission</div>
#  <div class="details">
#  <div class="price">$1,000</div>
#  <div class="location">
#                          CHARLOTTESVILLE
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1998 GMC Sierra 1500 SL Truck Auto RWD &lt;103,000 miles">
#  <a href="https://charlottesville.craigslist.org/cto/d/louisa-1998-gmc-sierra-1500-sl-truck/7785561584.html">
#  <div class="title">1998 GMC Sierra 1500 SL Truck Auto RWD &lt;103,000 miles</div>
#  <div class="details">
#  <div class="price">$6,250</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2006 Honda Pilot EXL FWD">
#  <a href="https://charlottesville.craigslist.org/cto/d/henrico-2006-honda-pilot-exl-fwd/7785499961.html">
#  <div class="title">2006 Honda Pilot EXL FWD</div>
#  <div class="details">
#  <div class="price">$4,700</div>
#  <div class="location">
#                          Short Pump
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2001 Jeep Grand Cherokee">
#  <a href="https://charlottesville.craigslist.org/cto/d/gordonsville-2001-jeep-grand-cherokee/7785490667.html">
#  <div class="title">2001 Jeep Grand Cherokee</div>
#  <div class="details">
#  <div class="price">$2,800</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2015 GMC Terrain - Good Condition">
#  <a href="https://charlottesville.craigslist.org/cto/d/keswick-2015-gmc-terrain-good-condition/7785267240.html">
#  <div class="title">2015 GMC Terrain - Good Condition</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          Keswick
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Buick">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-buick/7785078444.html">
#  <div class="title">Buick</div>
#  <div class="details">
#  <div class="price">$4,500</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2014 Ford Escape">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2014-ford-escape/7785060212.html">
#  <div class="title">2014 Ford Escape</div>
#  <div class="details">
#  <div class="price">$1,500</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Jeep Wrangler">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-jeep-wrangler/7785014681.html">
#  <div class="title">Jeep Wrangler</div>
#  <div class="details">
#  <div class="price">$12,500</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 Toyota Camry V6 XLE">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2007-toyota-camry-v6-xle/7785001447.html">
#  <div class="title">2007 Toyota Camry V6 XLE</div>
#  <div class="details">
#  <div class="price">$4,700</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1994 Chevy s10">
#  <a href="https://charlottesville.craigslist.org/cto/d/palmyra-1994-chevy-s10/7784965289.html">
#  <div class="title">1994 Chevy s10</div>
#  <div class="details">
#  <div class="price">$4,000</div>
#  <div class="location">
#                          Palmyra
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Toyota 4runner">
#  <a href="https://charlottesville.craigslist.org/cto/d/quinque-toyota-4runner/7784875544.html">
#  <div class="title">Toyota 4runner</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          Ruckersville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1962 m38-a1 military jeep">
#  <a href="https://charlottesville.craigslist.org/cto/d/scottsville-1962-m38-a1-military-jeep/7784860520.html">
#  <div class="title">1962 m38-a1 military jeep</div>
#  <div class="details">
#  <div class="price">$1,500</div>
#  <div class="location">
#                          Scottsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2010 avalanche">
#  <a href="https://charlottesville.craigslist.org/cto/d/mineral-2010-avalanche/7784792017.html">
#  <div class="title">2010 avalanche</div>
#  <div class="details">
#  <div class="price">$5,500</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Dodge M37 Powerwagon">
#  <a href="https://charlottesville.craigslist.org/cto/d/piney-river-dodge-m37-powerwagon/7784758445.html">
#  <div class="title">Dodge M37 Powerwagon</div>
#  <div class="details">
#  <div class="price">$7,000</div>
#  <div class="location">
#                          Roseland
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2018 Toyota Tacoma Truck SR5 4WD double cab, 6 cyl, auto, 30,000 miles">
#  <a href="https://charlottesville.craigslist.org/cto/d/louisa-2018-toyota-tacoma-truck-sr5-4wd/7784680777.html">
#  <div class="title">2018 Toyota Tacoma Truck SR5 4WD double cab, 6 cyl, auto, 30,000 miles</div>
#  <div class="details">
#  <div class="price">$30,750</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2003 Toyota Highlander">
#  <a href="https://charlottesville.craigslist.org/cto/d/lovingston-2003-toyota-highlander/7784607564.html">
#  <div class="title">2003 Toyota Highlander</div>
#  <div class="details">
#  <div class="price">$3,300</div>
#  <div class="location">
#                          Lovingston
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2011 Chrysler Town and Country">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2011-chrysler-town-and/7784233445.html">
#  <div class="title">2011 Chrysler Town and Country</div>
#  <div class="details">
#  <div class="price">$2,500</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2006 Mitsubishi Endeavor AWD LS">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2006-mitsubishi/7784157813.html">
#  <div class="title">2006 Mitsubishi Endeavor AWD LS</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2019 Hyundai Kona excellent condition">
#  <a href="https://charlottesville.craigslist.org/cto/d/barboursville-2019-hyundai-kona/7783977835.html">
#  <div class="title">2019 Hyundai Kona excellent condition</div>
#  <div class="details">
#  <div class="price">$15,000</div>
#  <div class="location">
#                          Barboursville  VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2011 BMW 328i xDrive Sedan 4D">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2011-bmw-328i-xdrive/7783905386.html">
#  <div class="title">2011 BMW 328i xDrive Sedan 4D</div>
#  <div class="details">
#  <div class="price">$6,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2008 Subaru Outback">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2008-subaru-outback/7783889756.html">
#  <div class="title">2008 Subaru Outback</div>
#  <div class="details">
#  <div class="price">$5,800</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2004 Dodge Durango">
#  <a href="https://charlottesville.craigslist.org/cto/d/stanardsville-2004-dodge-durango/7783863430.html">
#  <div class="title">2004 Dodge Durango</div>
#  <div class="details">
#  <div class="price">$2,000</div>
#  <div class="location">
#                          Stanardsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2012 Ford Focus SE">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2012-ford-focus-se/7783801610.html">
#  <div class="title">2012 Ford Focus SE</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          Free Union
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2008 Ford Escape XLT 4x4 3.0">
#  <a href="https://charlottesville.craigslist.org/cto/d/earlysville-2008-ford-escape-xlt-4x4-30/7783759838.html">
#  <div class="title">2008 Ford Escape XLT 4x4 3.0</div>
#  <div class="details">
#  <div class="price">$1,500</div>
#  <div class="location">
#                          Earlysville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Mercedes 560sl">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-mercedes-560sl/7783648170.html">
#  <div class="title">Mercedes 560sl</div>
#  <div class="details">
#  <div class="price">$15,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2013 Honda Fit Sport Hatchback">
#  <a href="https://charlottesville.craigslist.org/cto/d/afton-2013-honda-fit-sport-hatchback/7783561831.html">
#  <div class="title">2013 Honda Fit Sport Hatchback</div>
#  <div class="details">
#  <div class="price">$8,700</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1986 Ford E350 Centurion">
#  <a href="https://charlottesville.craigslist.org/cto/d/helena-1986-ford-e350-centurion/7783532418.html">
#  <div class="title">1986 Ford E350 Centurion</div>
#  <div class="details">
#  <div class="price">$11,500</div>
#  <div class="location">
#                          Helena
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2014 Honda Odyssey Van Black">
#  <a href="https://charlottesville.craigslist.org/cto/d/scottsville-2014-honda-odyssey-van-black/7783477164.html">
#  <div class="title">2014 Honda Odyssey Van Black</div>
#  <div class="details">
#  <div class="price">$12,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Military Truck W/Crane">
#  <a href="https://charlottesville.craigslist.org/cto/d/free-union-military-truck-crane/7783324663.html">
#  <div class="title">Military Truck W/Crane</div>
#  <div class="details">
#  <div class="price">$6,200</div>
#  <div class="location">
#                          Free Union, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Volvo S40 4Dr Sedan 2004 Power everything sun roof">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-volvo-s40-4dr-sedan/7783322114.html">
#  <div class="title">Volvo S40 4Dr Sedan 2004 Power everything sun roof</div>
#  <div class="details">
#  <div class="price">$2,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2004 honda accord for sale $5,500 or best offer">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2004-honda-accord-for/7783266346.html">
#  <div class="title">2004 honda accord for sale $5,500 or best offer</div>
#  <div class="details">
#  <div class="price">$5,500</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2003 Honda Pilot">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2003-honda-pilot/7783239203.html">
#  <div class="title">2003 Honda Pilot</div>
#  <div class="details">
#  <div class="price">$1,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2002 Chevy Tahoe 4WD">
#  <a href="https://charlottesville.craigslist.org/cto/d/montpelier-station-2002-chevy-tahoe-4wd/7783219894.html">
#  <div class="title">2002 Chevy Tahoe 4WD</div>
#  <div class="details">
#  <div class="price">$4,000</div>
#  <div class="location">
#                          Gordonsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2008 Nissan Altima (read description)">
#  <a href="https://charlottesville.craigslist.org/cto/d/ruckersville-2008-nissan-altima-read-de/7783180089.html">
#  <div class="title">2008 Nissan Altima (read description)</div>
#  <div class="details">
#  <div class="price">$1,350</div>
#  <div class="location">
#                          Ruckersville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2016 Tesla Model S 90D">
#  <a href="https://charlottesville.craigslist.org/cto/d/crozet-2016-tesla-model-90d/7783168254.html">
#  <div class="title">2016 Tesla Model S 90D</div>
#  <div class="details">
#  <div class="price">$26,000</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2010 Volkswagen Golf">
#  <a href="https://charlottesville.craigslist.org/cto/d/henrico-2010-volkswagen-golf/7783125171.html">
#  <div class="title">2010 Volkswagen Golf</div>
#  <div class="details">
#  <div class="price">$4,950</div>
#  <div class="location">
#                          Short Pump
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1963 /1965 Triumph TR4 Convertible">
#  <a href="https://charlottesville.craigslist.org/cto/d/woodberry-forest-triumph-tr4-convertible/7782965513.html">
#  <div class="title">1963 /1965 Triumph TR4 Convertible</div>
#  <div class="details">
#  <div class="price">$2,250</div>
#  <div class="location">
#                          Orange
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1998 Jeep Grande Cherokee Laredo">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-1998-jeep-grande-cherokee/7782899240.html">
#  <div class="title">1998 Jeep Grande Cherokee Laredo</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1996 Chevrolet K1500 Z71">
#  <a href="https://charlottesville.craigslist.org/cto/d/keswick-1996-chevrolet-k1500-z71/7782892110.html">
#  <div class="title">1996 Chevrolet K1500 Z71</div>
#  <div class="details">
#  <div class="price">$6,500</div>
#  <div class="location">
#                          Keswick
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1971 Sport Convertible">
#  <a href="https://charlottesville.craigslist.org/cto/d/culpeper-1971-sport-convertible/7782818548.html">
#  <div class="title">1971 Sport Convertible</div>
#  <div class="details">
#  <div class="price">$25,000</div>
#  <div class="location">
#                          Culpeper
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Dodge Dakota 4wd">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-dodge-dakota-4wd/7782614108.html">
#  <div class="title">Dodge Dakota 4wd</div>
#  <div class="details">
#  <div class="price">$10,000</div>
#  <div class="location">
#                          Downtown
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2014 BMW X3 with Blown Engine">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2014-bmw-x3-with-blown/7782218430.html">
#  <div class="title">2014 BMW X3 with Blown Engine</div>
#  <div class="details">
#  <div class="price">$3,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Ford f150 5.4 Triton">
#  <a href="https://charlottesville.craigslist.org/cto/d/fishersville-ford-triton/7782209120.html">
#  <div class="title">Ford f150 5.4 Triton</div>
#  <div class="details">
#  <div class="price">$7,250</div>
#  <div class="location">
#                          Fishersville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 Ford XLT FX, 4-Dr., Supercab, Sidestyle, 5.4-liter V8">
#  <a href="https://charlottesville.craigslist.org/cto/d/crozet-2007-ford-xlt-fx-dr-supercab/7782091017.html">
#  <div class="title">2007 Ford XLT FX, 4-Dr., Supercab, Sidestyle, 5.4-liter V8</div>
#  <div class="details">
#  <div class="price">$8,300</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1999 Mx-5 miata covertible coupe">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-1999-mx-miata/7781918639.html">
#  <div class="title">1999 Mx-5 miata covertible coupe</div>
#  <div class="details">
#  <div class="price">$6,500</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Dodge 4x4 SLT">
#  <a href="https://charlottesville.craigslist.org/cto/d/crozet-dodge-4x4-slt/7781868229.html">
#  <div class="title">Dodge 4x4 SLT</div>
#  <div class="details">
#  <div class="price">$6,000</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1992 Honda accord Gas sipper">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-1992-honda-accord-gas/7781862579.html">
#  <div class="title">1992 Honda accord Gas sipper</div>
#  <div class="details">
#  <div class="price">$2,899</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2003 Jeep Wrangler">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2003-jeep-wrangler/7781774156.html">
#  <div class="title">2003 Jeep Wrangler</div>
#  <div class="details">
#  <div class="price">$20,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Yes I have title">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-yes-have-title/7781670977.html">
#  <div class="title">Yes I have title</div>
#  <div class="details">
#  <div class="price">$2,800</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2016 Kia Sorento">
#  <a href="https://charlottesville.craigslist.org/cto/d/haywood-2016-kia-sorento/7781590995.html">
#  <div class="title">2016 Kia Sorento</div>
#  <div class="details">
#  <div class="price">$9,500</div>
#  <div class="location">
#                          Madison
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2008 Acura TL">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2008-acura-tl/7781590435.html">
#  <div class="title">2008 Acura TL</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          Chville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="*FOR SALE* Subaru outback 2007">
#  <a href="https://charlottesville.craigslist.org/cto/d/gordonsville-for-sale-subaru-outback/7781590306.html">
#  <div class="title">*FOR SALE* Subaru outback 2007</div>
#  <div class="details">
#  <div class="price">$3,900</div>
#  <div class="location">
#                          Gordonsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Audi Allroad">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-audi-allroad/7781459189.html">
#  <div class="title">Audi Allroad</div>
#  <div class="details">
#  <div class="price">$11,665</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2004 f150">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2004-f150/7781429289.html">
#  <div class="title">2004 f150</div>
#  <div class="details">
#  <div class="price">$3,000</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2011 Mercury Gran Marquis LS">
#  <a href="https://charlottesville.craigslist.org/cto/d/stanardsville-2011-mercury-gran-marquis/7781391243.html">
#  <div class="title">2011 Mercury Gran Marquis LS</div>
#  <div class="details">
#  <div class="price">$3,600</div>
#  <div class="location">
#                          Stanardsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Beautiful 2019 Mercedes 300C Convertible">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-beautiful-2019-mercedes/7781346288.html">
#  <div class="title">Beautiful 2019 Mercedes 300C Convertible</div>
#  <div class="details">
#  <div class="price">$31,950</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Toyota corolla 2018">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-toyota-corolla-2018/7781210696.html">
#  <div class="title">Toyota corolla 2018</div>
#  <div class="details">
#  <div class="price">$11,000</div>
#  <div class="location">
#                          Charlottesville Virginia
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="BMW X5">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-bmw-x5/7780668737.html">
#  <div class="title">BMW X5</div>
#  <div class="details">
#  <div class="price">$8,500</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2009 Kia Rondo EX 145K miles">
#  <a href="https://charlottesville.craigslist.org/cto/d/louisa-2009-kia-rondo-ex-145k-miles/7780623128.html">
#  <div class="title">2009 Kia Rondo EX 145K miles</div>
#  <div class="details">
#  <div class="price">$3,500</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2002 GMC 3500 4x4 Extended Cab Utility Bed">
#  <a href="https://charlottesville.craigslist.org/cto/d/piney-river-2002-gmc-x4-extended-cab/7780543822.html">
#  <div class="title">2002 GMC 3500 4x4 Extended Cab Utility Bed</div>
#  <div class="details">
#  <div class="price">$8,900</div>
#  <div class="location">
#                          Amherst
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="volvo 240 sedan 1992">
#  <a href="https://charlottesville.craigslist.org/cto/d/esmont-volvo-240-sedan-1992/7780475292.html">
#  <div class="title">volvo 240 sedan 1992</div>
#  <div class="details">
#  <div class="price">$2,100</div>
#  <div class="location">
#                          esmont
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2006 Hyundai Azera Limited">
#  <a href="https://charlottesville.craigslist.org/cto/d/quinque-2006-hyundai-azera-limited/7780464989.html">
#  <div class="title">2006 Hyundai Azera Limited</div>
#  <div class="details">
#  <div class="price">$3,250</div>
#  <div class="location">
#                          Ruckersville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2018 Subaru Forester 2.5i Touring CVT">
#  <a href="https://charlottesville.craigslist.org/cto/d/roseland-2018-subaru-forester-25i/7780319702.html">
#  <div class="title">2018 Subaru Forester 2.5i Touring CVT</div>
#  <div class="details">
#  <div class="price">$23,500</div>
#  <div class="location">
#                          Nelson County
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Car for Sale">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-car-for-sale/7780257892.html">
#  <div class="title">Car for Sale</div>
#  <div class="details">
#  <div class="price">$10,000</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1969 Chevelle for sale or trade">
#  <a href="https://charlottesville.craigslist.org/cto/d/barboursville-1969-chevelle-for-sale-or/7780220803.html">
#  <div class="title">1969 Chevelle for sale or trade</div>
#  <div class="details">
#  <div class="price">$28,500</div>
#  <div class="location">
#                          Barboursville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1989 Chevrolet Corvette Convertible">
#  <a href="https://charlottesville.craigslist.org/cto/d/scottsville-1989-chevrolet-corvette/7779874166.html">
#  <div class="title">1989 Chevrolet Corvette Convertible</div>
#  <div class="details">
#  <div class="price">$5,000</div>
#  <div class="location">
#                          Scottsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2008 Toyota Prius">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2008-toyota-prius/7779766112.html">
#  <div class="title">2008 Toyota Prius</div>
#  <div class="details">
#  <div class="price">$7,500</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2021 Toyota RAV 4 PRIME HYBRID">
#  <a href="https://charlottesville.craigslist.org/cto/d/earlysville-2021-toyota-rav-prime-hybrid/7779746384.html">
#  <div class="title">2021 Toyota RAV 4 PRIME HYBRID</div>
#  <div class="details">
#  <div class="price">$38,000</div>
#  <div class="location">
#                          EARLYSVILLE
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 2500 GMC Sierra HD Classic">
#  <a href="https://charlottesville.craigslist.org/cto/d/waynesboro-gmc-sierra-hd-classic/7779516916.html">
#  <div class="title">2007 2500 GMC Sierra HD Classic</div>
#  <div class="details">
#  <div class="price">$4,500</div>
#  <div class="location">
#                          waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2019 Ram Promaster 1500">
#  <a href="https://charlottesville.craigslist.org/cto/d/crozet-2019-ram-promaster-1500/7779509064.html">
#  <div class="title">2019 Ram Promaster 1500</div>
#  <div class="details">
#  <div class="price">$18,500</div>
#  <div class="location">
#                          Old Trail
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1958 ford fairlane 500">
#  <a href="https://charlottesville.craigslist.org/cto/d/leon-1958-ford-fairlane-500/7779305738.html">
#  <div class="title">1958 ford fairlane 500</div>
#  <div class="details">
#  <div class="price">$18,500</div>
#  <div class="location">
#                          Reva
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2014 Honda CRV EX-L">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2014-honda-crv-ex/7779300072.html">
#  <div class="title">2014 Honda CRV EX-L</div>
#  <div class="details">
#  <div class="price">$13,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2005 Ford F-150 2WD- Not Running">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2005-ford-150-2wd-not/7779296183.html">
#  <div class="title">2005 Ford F-150 2WD- Not Running</div>
#  <div class="details">
#  <div class="price">$1,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="BMW GT">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-bmw-gt/7779123777.html">
#  <div class="title">BMW GT</div>
#  <div class="details">
#  <div class="price">$10,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2001 Mercedes E320">
#  <a href="https://charlottesville.craigslist.org/cto/d/scottsville-2001-mercedes-e320/7779120462.html">
#  <div class="title">2001 Mercedes E320</div>
#  <div class="details">
#  <div class="price">$3,000</div>
#  <div class="location">
#                          Scottsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 SUBARU OUTBACK">
#  <a href="https://charlottesville.craigslist.org/cto/d/oakpark-2007-subaru-outback/7778984172.html">
#  <div class="title">2007 SUBARU OUTBACK</div>
#  <div class="details">
#  <div class="price">$2,500</div>
#  <div class="location">
#                          MADISON VA.
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1974 Dodge Stepside 426 Hemi">
#  <a href="https://charlottesville.craigslist.org/cto/d/leon-1974-dodge-stepside-426-hemi/7778782192.html">
#  <div class="title">1974 Dodge Stepside 426 Hemi</div>
#  <div class="details">
#  <div class="price">$10,500</div>
#  <div class="location">
#                          Reva
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2018 Tesla Model 3 Mid range OR 2018 Tesla Model S75D AWD">
#  <a href="https://charlottesville.craigslist.org/cto/d/henrico-2018-tesla-model-mid-range-or/7778737328.html">
#  <div class="title">2018 Tesla Model 3 Mid range OR 2018 Tesla Model S75D AWD</div>
#  <div class="details">
#  <div class="price">$16,900</div>
#  <div class="location">
#                          Short Pump
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 Ford Explorer">
#  <a href="https://charlottesville.craigslist.org/cto/d/dyke-2007-ford-explorer/7778524782.html">
#  <div class="title">2007 Ford Explorer</div>
#  <div class="details">
#  <div class="price">$2,000</div>
#  <div class="location">
#                          Dyke
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2013 Mercedes-Benz C 250 CLS 4D — very good condition">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2013-mercedes-benz-250/7778509247.html">
#  <div class="title">2013 Mercedes-Benz C 250 CLS 4D — very good condition</div>
#  <div class="details">
#  <div class="price">$7,999</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2017 Range Rover Black Edition OBO">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2017-range-rover-black/7778267901.html">
#  <div class="title">2017 Range Rover Black Edition OBO</div>
#  <div class="details">
#  <div class="price">$35,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2017 Ford Escape">
#  <a href="https://charlottesville.craigslist.org/cto/d/amherst-2017-ford-escape/7778011749.html">
#  <div class="title">2017 Ford Escape</div>
#  <div class="details">
#  <div class="price">$18,995</div>
#  <div class="location">
#                          Amherst County, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2008 Honda Crv EXL AWD">
#  <a href="https://charlottesville.craigslist.org/cto/d/charlottesville-2008-honda-crv-exl-awd/7777943177.html">
#  <div class="title">2008 Honda Crv EXL AWD</div>
#  <div class="details">
#  <div class="price">$5,300</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2016 Jeep Renegade Latitude * Great Condition - No Accidents *">
#  <a href="https://charlottesville.craigslist.org/cto/d/white-hall-2016-jeep-renegade-latitude/7777823914.html">
#  <div class="title">2016 Jeep Renegade Latitude * Great Condition - No Accidents *</div>
#  <div class="details">
#  <div class="price">$10,495</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1995 F-250">
#  <a href="https://charlottesville.craigslist.org/cto/d/stanardsville-1995-250/7777405295.html">
#  <div class="title">1995 F-250</div>
#  <div class="details">
#  <div class="price">$7,500</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 BMW 530i">
#  <a href="https://charlottesville.craigslist.org/cto/d/quinque-2007-bmw-530i/7777314629.html">
#  <div class="title">2007 BMW 530i</div>
#  <div class="details">
#  <div class="price">$1,800</div>
#  <div class="location">
#                          Ruckersville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2016 Hyundai Elantra GT">
#  <a href="https://charlottesville.craigslist.org/cto/d/crozet-2016-hyundai-elantra-gt/7777297196.html">
#  <div class="title">2016 Hyundai Elantra GT</div>
#  <div class="details">
#  <div class="price">$12,500</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2007 Mercedes Benz C280 or 2008 Benz E500 4Matic $3950">
#  <a href="https://charlottesville.craigslist.org/cto/d/henrico-2007-mercedes-benz-c280-or-2008/7777197591.html">
#  <div class="title">2007 Mercedes Benz C280 or 2008 Benz E500 4Matic $3950</div>
#  <div class="details">
#  <div class="price">$4,950</div>
#  <div class="location">
#                          Short Pump
#                      </div>
#  </div>
#  </a>
#  </li>]

# %%
listings[0].find(class_="title").get_text() #experiment with pulling info out of page, put together profile of what you want
# can use stackoverflow to search how to code certain things
# Out:
# '2015 Honda Odyssey EX'

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# For each listing, we'll use the `.find` method to search within the listing record for specific information. To get the information we want, we can then use `.get_text()`.
#
# In the code below, two more things happen.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %%
data
# Out:
# [{'title': '2015 honda odyssey ex',
#   'price': '$9,950',
#   'year': '2015',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2015-honda-odyssey-ex/7785813701.html',
#   'brand': 'honda'},
#  {'title': '2005 hyundai elantra',
#   'price': '$1,200',
#   'year': '2005',
#   'link': 'https://charlottesville.craigslist.org/cto/d/afton-2005-hyundai-elantra/7785683810.html',
#   'brand': 'missing'},
#  {'title': '2007 f250 king ranch',
#   'price': '$17,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-2007-f250-king-ranch/7785680751.html',
#   'brand': 'missing'},
#  {'title': '1997 dodge 2500 4x4 cummins',
#   'price': '$9,500',
#   'year': '1997',
#   'link': 'https://charlottesville.craigslist.org/cto/d/lovingston-1997-dodge-x4-cummins/7785609263.html',
#   'brand': 'dodge'},
#  {'title': '1999 honda civic 4 cyl manual transmission',
#   'price': '$1,000',
#   'year': '1999',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1999-honda-civic-cyl/7785580889.html',
#   'brand': 'honda'},
#  {'title': '1998 gmc sierra 1500 sl truck auto rwd <103,000 miles',
#   'price': '$6,250',
#   'year': '1998',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-1998-gmc-sierra-1500-sl-truck/7785561584.html',
#   'brand': 'gmc'},
#  {'title': '2006 honda pilot exl fwd',
#   'price': '$4,700',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2006-honda-pilot-exl-fwd/7785499961.html',
#   'brand': 'honda'},
#  {'title': '2001 jeep grand cherokee',
#   'price': '$2,800',
#   'year': '2001',
#   'link': 'https://charlottesville.craigslist.org/cto/d/gordonsville-2001-jeep-grand-cherokee/7785490667.html',
#   'brand': 'jeep'},
#  {'title': '2015 gmc terrain - good condition',
#   'price': '$3,500',
#   'year': '2015',
#   'link': 'https://charlottesville.craigslist.org/cto/d/keswick-2015-gmc-terrain-good-condition/7785267240.html',
#   'brand': 'gmc'},
#  {'title': 'buick',
#   'price': '$4,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-buick/7785078444.html',
#   'brand': 'buick'},
#  {'title': '2014 ford escape',
#   'price': '$1,500',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2014-ford-escape/7785060212.html',
#   'brand': 'ford'},
#  {'title': 'jeep wrangler',
#   'price': '$12,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-jeep-wrangler/7785014681.html',
#   'brand': 'jeep'},
#  {'title': '2007 toyota camry v6 xle',
#   'price': '$4,700',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2007-toyota-camry-v6-xle/7785001447.html',
#   'brand': 'toyota'},
#  {'title': '1994 chevy s10',
#   'price': '$4,000',
#   'year': '1994',
#   'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-1994-chevy-s10/7784965289.html',
#   'brand': 'chevy'},
#  {'title': 'toyota 4runner',
#   'price': '$3,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/quinque-toyota-4runner/7784875544.html',
#   'brand': 'toyota'},
#  {'title': '1962 m38-a1 military jeep',
#   'price': '$1,500',
#   'year': '1962',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-1962-m38-a1-military-jeep/7784860520.html',
#   'brand': 'jeep'},
#  {'title': '2010 avalanche',
#   'price': '$5,500',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/mineral-2010-avalanche/7784792017.html',
#   'brand': 'missing'},
#  {'title': 'dodge m37 powerwagon',
#   'price': '$7,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/piney-river-dodge-m37-powerwagon/7784758445.html',
#   'brand': 'dodge'},
#  {'title': '2018 toyota tacoma truck sr5 4wd double cab, 6 cyl, auto, 30,000 miles',
#   'price': '$30,750',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-2018-toyota-tacoma-truck-sr5-4wd/7784680777.html',
#   'brand': 'toyota'},
#  {'title': '2003 toyota highlander',
#   'price': '$3,300',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/lovingston-2003-toyota-highlander/7784607564.html',
#   'brand': 'toyota'},
#  {'title': '2011 chrysler town and country',
#   'price': '$2,500',
#   'year': '2011',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2011-chrysler-town-and/7784233445.html',
#   'brand': 'missing'},
#  {'title': '2006 mitsubishi endeavor awd ls',
#   'price': '$3,500',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2006-mitsubishi/7784157813.html',
#   'brand': 'mitsubishi'},
#  {'title': '2019 hyundai kona excellent condition',
#   'price': '$15,000',
#   'year': '2019',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-2019-hyundai-kona/7783977835.html',
#   'brand': 'missing'},
#  {'title': '2011 bmw 328i xdrive sedan 4d',
#   'price': '$6,000',
#   'year': '2011',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2011-bmw-328i-xdrive/7783905386.html',
#   'brand': 'bmw'},
#  {'title': '2008 subaru outback',
#   'price': '$5,800',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-subaru-outback/7783889756.html',
#   'brand': 'subaru'},
#  {'title': '2004 dodge durango',
#   'price': '$2,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/stanardsville-2004-dodge-durango/7783863430.html',
#   'brand': 'dodge'},
#  {'title': '2012 ford focus se',
#   'price': '$3,500',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2012-ford-focus-se/7783801610.html',
#   'brand': 'ford'},
#  {'title': '2008 ford escape xlt 4x4 3.0',
#   'price': '$1,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/earlysville-2008-ford-escape-xlt-4x4-30/7783759838.html',
#   'brand': 'ford'},
#  {'title': 'mercedes 560sl',
#   'price': '$15,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-mercedes-560sl/7783648170.html',
#   'brand': 'missing'},
#  {'title': '2013 honda fit sport hatchback',
#   'price': '$8,700',
#   'year': '2013',
#   'link': 'https://charlottesville.craigslist.org/cto/d/afton-2013-honda-fit-sport-hatchback/7783561831.html',
#   'brand': 'honda'},
#  {'title': '1986 ford e350 centurion',
#   'price': '$11,500',
#   'year': '1986',
#   'link': 'https://charlottesville.craigslist.org/cto/d/helena-1986-ford-e350-centurion/7783532418.html',
#   'brand': 'ford'},
#  {'title': '2014 honda odyssey van black',
#   'price': '$12,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2014-honda-odyssey-van-black/7783477164.html',
#   'brand': 'honda'},
#  {'title': 'military truck w/crane',
#   'price': '$6,200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/free-union-military-truck-crane/7783324663.html',
#   'brand': 'missing'},
#  {'title': 'volvo s40 4dr sedan 2004 power everything sun roof',
#   'price': '$2,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-volvo-s40-4dr-sedan/7783322114.html',
#   'brand': 'volvo'},
#  {'title': '2004 honda accord for sale $5,500 or best offer',
#   'price': '$5,500',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-honda-accord-for/7783266346.html',
#   'brand': 'honda'},
#  {'title': '2003 honda pilot',
#   'price': '$1,000',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2003-honda-pilot/7783239203.html',
#   'brand': 'honda'},
#  {'title': '2002 chevy tahoe 4wd',
#   'price': '$4,000',
#   'year': '2002',
#   'link': 'https://charlottesville.craigslist.org/cto/d/montpelier-station-2002-chevy-tahoe-4wd/7783219894.html',
#   'brand': 'chevy'},
#  {'title': '2008 nissan altima (read description)',
#   'price': '$1,350',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/ruckersville-2008-nissan-altima-read-de/7783180089.html',
#   'brand': 'missing'},
#  {'title': '2016 tesla model s 90d',
#   'price': '$26,000',
#   'year': '2016',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2016-tesla-model-90d/7783168254.html',
#   'brand': 'tesla'},
#  {'title': '2010 volkswagen golf',
#   'price': '$4,950',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2010-volkswagen-golf/7783125171.html',
#   'brand': 'volkswagen'},
#  {'title': '1963 /1965 triumph tr4 convertible',
#   'price': '$2,250',
#   'year': '1963',
#   'link': 'https://charlottesville.craigslist.org/cto/d/woodberry-forest-triumph-tr4-convertible/7782965513.html',
#   'brand': 'missing'},
#  {'title': '1998 jeep grande cherokee laredo',
#   'price': '$3,500',
#   'year': '1998',
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-1998-jeep-grande-cherokee/7782899240.html',
#   'brand': 'jeep'},
#  {'title': '1996 chevrolet k1500 z71',
#   'price': '$6,500',
#   'year': '1996',
#   'link': 'https://charlottesville.craigslist.org/cto/d/keswick-1996-chevrolet-k1500-z71/7782892110.html',
#   'brand': 'chevrolet'},
#  {'title': '1971 sport convertible',
#   'price': '$25,000',
#   'year': '1971',
#   'link': 'https://charlottesville.craigslist.org/cto/d/culpeper-1971-sport-convertible/7782818548.html',
#   'brand': 'missing'},
#  {'title': 'dodge dakota 4wd',
#   'price': '$10,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-dodge-dakota-4wd/7782614108.html',
#   'brand': 'dodge'},
#  {'title': '2014 bmw x3 with blown engine',
#   'price': '$3,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2014-bmw-x3-with-blown/7782218430.html',
#   'brand': 'bmw'},
#  {'title': 'ford f150 5.4 triton',
#   'price': '$7,250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/fishersville-ford-triton/7782209120.html',
#   'brand': 'ford'},
#  {'title': '2007 ford xlt fx, 4-dr., supercab, sidestyle, 5.4-liter v8',
#   'price': '$8,300',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2007-ford-xlt-fx-dr-supercab/7782091017.html',
#   'brand': 'ford'},
#  {'title': '1999 mx-5 miata covertible coupe',
#   'price': '$6,500',
#   'year': '1999',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1999-mx-miata/7781918639.html',
#   'brand': 'missing'},
#  {'title': 'dodge 4x4 slt',
#   'price': '$6,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-dodge-4x4-slt/7781868229.html',
#   'brand': 'dodge'},
#  {'title': '1992 honda accord gas sipper',
#   'price': '$2,899',
#   'year': '1992',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1992-honda-accord-gas/7781862579.html',
#   'brand': 'honda'},
#  {'title': '2003 jeep wrangler',
#   'price': '$20,000',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2003-jeep-wrangler/7781774156.html',
#   'brand': 'jeep'},
#  {'title': 'yes i have title',
#   'price': '$2,800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-yes-have-title/7781670977.html',
#   'brand': 'missing'},
#  {'title': '2016 kia sorento',
#   'price': '$9,500',
#   'year': '2016',
#   'link': 'https://charlottesville.craigslist.org/cto/d/haywood-2016-kia-sorento/7781590995.html',
#   'brand': 'kia'},
#  {'title': '2008 acura tl',
#   'price': '$3,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-acura-tl/7781590435.html',
#   'brand': 'acura'},
#  {'title': '*for sale* subaru outback 2007',
#   'price': '$3,900',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/gordonsville-for-sale-subaru-outback/7781590306.html',
#   'brand': 'subaru'},
#  {'title': 'audi allroad',
#   'price': '$11,665',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-audi-allroad/7781459189.html',
#   'brand': 'audi'},
#  {'title': '2004 f150',
#   'price': '$3,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-f150/7781429289.html',
#   'brand': 'missing'},
#  {'title': '2011 mercury gran marquis ls',
#   'price': '$3,600',
#   'year': '2011',
#   'link': 'https://charlottesville.craigslist.org/cto/d/stanardsville-2011-mercury-gran-marquis/7781391243.html',
#   'brand': 'missing'},
#  {'title': 'beautiful 2019 mercedes 300c convertible',
#   'price': '$31,950',
#   'year': '2019',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-beautiful-2019-mercedes/7781346288.html',
#   'brand': 'missing'},
#  {'title': 'toyota corolla 2018',
#   'price': '$11,000',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-toyota-corolla-2018/7781210696.html',
#   'brand': 'toyota'},
#  {'title': 'bmw x5',
#   'price': '$8,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-bmw-x5/7780668737.html',
#   'brand': 'bmw'},
#  {'title': '2009 kia rondo ex 145k miles',
#   'price': '$3,500',
#   'year': '2009',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-2009-kia-rondo-ex-145k-miles/7780623128.html',
#   'brand': 'kia'},
#  {'title': '2002 gmc 3500 4x4 extended cab utility bed',
#   'price': '$8,900',
#   'year': '2002',
#   'link': 'https://charlottesville.craigslist.org/cto/d/piney-river-2002-gmc-x4-extended-cab/7780543822.html',
#   'brand': 'gmc'},
#  {'title': 'volvo 240 sedan 1992',
#   'price': '$2,100',
#   'year': '1992',
#   'link': 'https://charlottesville.craigslist.org/cto/d/esmont-volvo-240-sedan-1992/7780475292.html',
#   'brand': 'volvo'},
#  {'title': '2006 hyundai azera limited',
#   'price': '$3,250',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/quinque-2006-hyundai-azera-limited/7780464989.html',
#   'brand': 'missing'},
#  {'title': '2018 subaru forester 2.5i touring cvt',
#   'price': '$23,500',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/roseland-2018-subaru-forester-25i/7780319702.html',
#   'brand': 'subaru'},
#  {'title': 'car for sale',
#   'price': '$10,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-car-for-sale/7780257892.html',
#   'brand': 'missing'},
#  {'title': '1969 chevelle for sale or trade',
#   'price': '$28,500',
#   'year': '1969',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-1969-chevelle-for-sale-or/7780220803.html',
#   'brand': 'missing'},
#  {'title': '1989 chevrolet corvette convertible',
#   'price': '$5,000',
#   'year': '1989',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-1989-chevrolet-corvette/7779874166.html',
#   'brand': 'chevrolet'},
#  {'title': '2008 toyota prius',
#   'price': '$7,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-toyota-prius/7779766112.html',
#   'brand': 'toyota'},
#  {'title': '2021 toyota rav 4 prime hybrid',
#   'price': '$38,000',
#   'year': '2021',
#   'link': 'https://charlottesville.craigslist.org/cto/d/earlysville-2021-toyota-rav-prime-hybrid/7779746384.html',
#   'brand': 'toyota'},
#  {'title': '2007 2500 gmc sierra hd classic',
#   'price': '$4,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-gmc-sierra-hd-classic/7779516916.html',
#   'brand': 'gmc'},
#  {'title': '2019 ram promaster 1500',
#   'price': '$18,500',
#   'year': '2019',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2019-ram-promaster-1500/7779509064.html',
#   'brand': 'missing'},
#  {'title': '1958 ford fairlane 500',
#   'price': '$18,500',
#   'year': '1958',
#   'link': 'https://charlottesville.craigslist.org/cto/d/leon-1958-ford-fairlane-500/7779305738.html',
#   'brand': 'ford'},
#  {'title': '2014 honda crv ex-l',
#   'price': '$13,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2014-honda-crv-ex/7779300072.html',
#   'brand': 'honda'},
#  {'title': '2005 ford f-150 2wd- not running',
#   'price': '$1,000',
#   'year': '2005',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2005-ford-150-2wd-not/7779296183.html',
#   'brand': 'ford'},
#  {'title': 'bmw gt',
#   'price': '$10,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-bmw-gt/7779123777.html',
#   'brand': 'bmw'},
#  {'title': '2001 mercedes e320',
#   'price': '$3,000',
#   'year': '2001',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2001-mercedes-e320/7779120462.html',
#   'brand': 'missing'},
#  {'title': '2007 subaru outback',
#   'price': '$2,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/oakpark-2007-subaru-outback/7778984172.html',
#   'brand': 'subaru'},
#  {'title': '1974 dodge stepside 426 hemi',
#   'price': '$10,500',
#   'year': '1974',
#   'link': 'https://charlottesville.craigslist.org/cto/d/leon-1974-dodge-stepside-426-hemi/7778782192.html',
#   'brand': 'dodge'},
#  {'title': '2018 tesla model 3 mid range or 2018 tesla model s75d awd',
#   'price': '$16,900',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2018-tesla-model-mid-range-or/7778737328.html',
#   'brand': 'tesla'},
#  {'title': '2007 ford explorer',
#   'price': '$2,000',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/dyke-2007-ford-explorer/7778524782.html',
#   'brand': 'ford'},
#  {'title': '2013 mercedes-benz c 250 cls 4d — very good condition',
#   'price': '$7,999',
#   'year': '2013',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2013-mercedes-benz-250/7778509247.html',
#   'brand': 'missing'},
#  {'title': '2017 range rover black edition obo',
#   'price': '$35,000',
#   'year': '2017',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2017-range-rover-black/7778267901.html',
#   'brand': 'missing'},
#  {'title': '2017 ford escape',
#   'price': '$18,995',
#   'year': '2017',
#   'link': 'https://charlottesville.craigslist.org/cto/d/amherst-2017-ford-escape/7778011749.html',
#   'brand': 'ford'},
#  {'title': '2008 honda crv exl awd',
#   'price': '$5,300',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-honda-crv-exl-awd/7777943177.html',
#   'brand': 'honda'},
#  {'title': '2016 jeep renegade latitude * great condition - no accidents *',
#   'price': '$10,495',
#   'year': '2016',
#   'link': 'https://charlottesville.craigslist.org/cto/d/white-hall-2016-jeep-renegade-latitude/7777823914.html',
#   'brand': 'jeep'},
#  {'title': '1995 f-250',
#   'price': '$7,500',
#   'year': '1995',
#   'link': 'https://charlottesville.craigslist.org/cto/d/stanardsville-1995-250/7777405295.html',
#   'brand': 'missing'},
#  {'title': '2007 bmw 530i',
#   'price': '$1,800',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/quinque-2007-bmw-530i/7777314629.html',
#   'brand': 'bmw'},
#  {'title': '2016 hyundai elantra gt',
#   'price': '$12,500',
#   'year': '2016',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2016-hyundai-elantra-gt/7777297196.html',
#   'brand': 'missing'},
#  {'title': '2007 mercedes benz c280 or 2008 benz e500 4matic $3950',
#   'price': '$4,950',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2007-mercedes-benz-c280-or-2008/7777197591.html',
#   'brand': 'missing'}]

# %% [markdown]
# ## 2. Get your search results of interest and extract data from them, using code similar to what's above.

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (92, 6)
#                                         title  price    year  \
# 0                       2015 honda odyssey ex   9950  2015.0
# 1                        2005 hyundai elantra   1200  2005.0
# 2                        2007 f250 king ranch  17500  2007.0
# 3                 1997 dodge 2500 4x4 cummins   9500  1997.0
# 4  1999 honda civic 4 cyl manual transmission   1000  1999.0
#
#                                                 link    brand   age
# 0  https://charlottesville.craigslist.org/cto/d/h...    honda  10.0
# 1  https://charlottesville.craigslist.org/cto/d/a...  missing  20.0
# 2  https://charlottesville.craigslist.org/cto/d/w...  missing  18.0
# 3  https://charlottesville.craigslist.org/cto/d/l...    dodge  28.0
# 4  https://charlottesville.craigslist.org/cto/d/c...    honda  26.0

# %% [markdown]
# With the data in and wrangled, we can now do EDA:

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       92.000000
# mean      8684.271739
# std       8134.930461
# min       1000.000000
# 25%       3287.500000
# 50%       5900.000000
# 75%      10625.000000
# max      38000.000000
# Name: price, dtype: float64
# count    78.000000
# mean     20.692308
# std      13.491034
# min       4.000000
# 25%      11.250000
# 50%      18.000000
# 75%      23.750000
# max      67.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# acura        1.0   3500.000000           NaN   3500.0   3500.00   3500.0
# audi         1.0  11665.000000           NaN  11665.0  11665.00  11665.0
# bmw          5.0   5860.000000   3492.563528   1800.0   3000.00   6000.0
# buick        1.0   4500.000000           NaN   4500.0   4500.00   4500.0
# chevrolet    2.0   5750.000000   1060.660172   5000.0   5375.00   5750.0
# chevy        2.0   4000.000000      0.000000   4000.0   4000.00   4000.0
# dodge        6.0   7500.000000   3224.903099   2000.0   6250.00   8250.0
# ford        10.0   7404.500000   6914.126622   1000.0   1625.00   5375.0
# gmc          4.0   5787.500000   2365.859604   3500.0   4250.00   5375.0
# honda       10.0   6404.900000   4324.340167   1000.0   3349.25   5400.0
# jeep         6.0   8465.833333   7193.233221   1500.0   2975.00   6997.5
# kia          2.0   6500.000000   4242.640687   3500.0   5000.00   6500.0
# missing     25.0  10821.960000  10061.365971   1200.0   3000.00   6500.0
# mitsubishi   1.0   3500.000000           NaN   3500.0   3500.00   3500.0
# subaru       4.0   8925.000000   9810.326192   2500.0   3550.00   4850.0
# tesla        2.0  21450.000000   6434.671709  16900.0  19175.00  21450.0
# toyota       7.0  14107.142857  14253.433170   3300.0   4100.00   7500.0
# volkswagen   1.0   4950.000000           NaN   4950.0   4950.00   4950.0
# volvo        2.0   2050.000000     70.710678   2000.0   2025.00   2050.0
#
#
#                  75%      max
# brand
# acura        3500.00   3500.0
# audi        11665.00  11665.0
# bmw          8500.00  10000.0
# buick        4500.00   4500.0
# chevrolet    6125.00   6500.0
# chevy        4000.00   4000.0
# dodge        9875.00  10500.0
# ford        10700.00  18995.0
# gmc          6912.50   8900.0
# honda        9637.50  13000.0
# jeep        11998.75  20000.0
# kia          8000.00   9500.0
# missing     15000.00  35000.0
# mitsubishi   3500.00   3500.0
# subaru      10225.00  23500.0
# tesla       23725.00  26000.0
# toyota      20875.00  38000.0
# volkswagen   4950.00   4950.0
# volvo        2075.00   2100.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min    25%   50%    75%   max
# brand
# acura        1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# audi         0.0        NaN        NaN   NaN    NaN   NaN    NaN   NaN
# bmw          3.0  14.333333   3.511885  11.0  12.50  14.0  16.00  18.0
# buick        0.0        NaN        NaN   NaN    NaN   NaN    NaN   NaN
# chevrolet    2.0  32.500000   4.949747  29.0  30.75  32.5  34.25  36.0
# chevy        2.0  27.000000   5.656854  23.0  25.00  27.0  29.00  31.0
# dodge        3.0  33.333333  15.695010  21.0  24.50  28.0  39.50  51.0
# ford         9.0  23.444444  18.554724   8.0  13.00  18.0  20.00  67.0
# gmc          4.0  19.500000   7.325754  10.0  16.00  20.5  24.00  27.0
# honda       10.0  18.200000   7.554248  10.0  11.25  18.0  21.75  33.0
# jeep         5.0  29.000000  20.211383   9.0  22.00  24.0  27.00  63.0
# kia          2.0  12.500000   4.949747   9.0  10.75  12.5  14.25  16.0
# missing     21.0  21.666667  16.344214   6.0  12.00  18.0  24.00  62.0
# mitsubishi   1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# subaru       4.0  15.000000   5.354126   7.0  14.50  17.5  18.00  18.0
# tesla        2.0   8.000000   1.414214   7.0   7.50   8.0   8.50   9.0
# toyota       6.0  12.500000   7.395945   4.0   7.00  12.0  17.75  22.0
# volkswagen   1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# volvo        2.0  27.000000   8.485281  21.0  24.00  27.0  30.00  33.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   0.790041 -0.202598
# log_age    -0.202598  0.354491
#            log_price   log_age
# log_price   1.000000 -0.362195
# log_age    -0.362195  1.000000

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %% [markdown]
# ## 3. Wrangle your data, do some EDA, and make some plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# The final thing we want to do is go from scraping a single page to crawling around.
#
# The idea here is that every web page is connected to some other page. By extracting links as we move from page to page, we can create a web crawler that wanders around for us, gathering information of interest.
#
# In this case, we want to use the search results to then visit each individual page for each listing. Since we saved the links to the web pages in the previous scrape, we can now simply for-loop over that column in the dataframe, visiting the page listing for each of the cars in the search results:

# %%
import time # Time delays
import random # Random numbers

links = df['link']
data = []
for link in links: # about 3 minutes
    time.sleep(random.randint(1, 3)) # Random delays
    raw = requests.get(link,headers=header) # Get page
    bsObj = soup(raw.content,'html.parser') # Parse the html
    #
    try:
        year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
    except:
        year_post = np.nan
    #
    try:
        condition = bsObj.find(class_='attr condition').find(href=True).get_text()
    except:
        condition = 'missing'
    #
    try:
        cylinders = bsObj.find(class_='attr auto_cylinders').find(class_ = 'valu').get_text()
        cylinders = cylinders.replace('\n','')
    except:
        cylinders = 'missing'
    #
    try:
        drivetrain = bsObj.find(class_='attr auto_drivetrain').find(href=True).get_text()
    except:
        drivetrain = 'missing'
    #
    try:
        fuel = bsObj.find(class_='attr auto_fuel_type').find(href = True).get_text()
    except:
        fuel = 'missing'
    #
    try:
        miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
    except:
        miles = np.nan
    #
    try:
        color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
    except:
        color='missing'
    #
    try:
        title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
    except:
        title='missing'
    #
    try:
        transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
    except:
        transmission = 'missing'
    #
    try:
        bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
    except:
        bodytype = 'missing'
    #
    text = bsObj.find(id='postingbody').get_text()
    text = text.replace('\n','')
    text = text.replace('QR Code Link to This Post','')
    record = {'title':title,
              'year_post':year_post,
              'condition':condition,
              'cylinders':cylinders,
              'drivetrain':drivetrain,
              'fuel':fuel,
              'miles':miles,
              'color':color,
              'title':'title',
              'transmission':transmission,
              'bodytype':bodytype,
              'text':text,}
    data.append(record)

# %% [markdown]
# What are the new features here?
#
# First, we don't want to overwhelm the servers, so we put a small delay between each request of a listing, `time.sleep(random.randint(1, 3))`. This waits a random amount of time between 1 and 3 seconds to avoid overwhelming their server.
#
# Second, we use the try/except block. This is a useful control structure in general, but especially for web scraping. Python tries the statements under `try:`, and if it fails, executes the steps under `except:`. This can happen, in this case, with missing data, which crashes the crawler. Instead, we put our missing codes into our dataframe right away.
#
# Third, we used `.find().find().get_text()` to find the data we're looking for. In general, the structure of mark-up langauges like HTML and XML makes it possible to "drill down" into their entries and extract the information of interest. This exploitation of mark-up languages could be the subject of a whole course on procuring data from the web.

# %% [markdown]
# With the data scraped, we can make a new dataframe, combine it with the old one using `pd.concat`, and do some wrangling to clean the data up:

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()

df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()

df['miles'] = df['miles'].str.replace(',','')
df['miles'] = pd.to_numeric(df['miles'],errors='coerce')

df['year_post'] = df['year_post'].str.replace(',','')
df['year_post'] = pd.to_numeric(df['year_post'],errors='coerce')
df.to_csv('craiglist_cville_cars_long.csv')

# %% [markdown]
# ## 4. From your search results, crawl to the links and extract more information about every listing in your original dataframe. Wrangle and do some EDA.
